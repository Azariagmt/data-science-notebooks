# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


under_18_users = [10, 100, 190, 300]
above_40_users = [20, 50, 90, 40]

year = [2008, 2009, 2010, 2011]

plt.plot(year, under_18_users)
plt.plot(year,above_40_users)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

under_18_users = [10, 100, 190, 300]
above_40_users = [20, 50, 90, 40]

year_one = [2008, 2009, 2010, 2011]
year_two = [2007, 2006, 2012, 2015]

plt.bar(year_one, under_18_users)
plt.bar(year_two, above_40_users)

plt.ioff()

# %%
file_path = '/home/azi/Desktop/Ex_Files_Python_Data_Science_EssT_Pt_1/Exercise Files/Data/mtcars.csv'

cars = pd.read_csv(file_path)
cars.columns = ['car_name', 'mpg', 'cyl', 'disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
cars.head()
cars = cars[0:5]
import matplotlib.pyplot as plt
plt.bar(cars['car_name'], cars['mpg'])

plt.pie(cars['hp'])
cars.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-8c81b772effe> in <module>
#       8 plt.bar(cars['car_name'], cars['mpg'])
#       9
# ---> 10 plt.pie(cars['hp'], label = 'hp')
#      11 cars.plot()
#
# TypeError: pie() got an unexpected keyword argument 'label'
